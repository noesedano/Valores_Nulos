# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as pit

# %%
#carga desde un archivo csv
data =pd.read_csv("Ventas_totales.csv")
data.head(5)
# Out:
#   indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0    01/01/2017                    27858.9                    27477.3
# 1    01/02/2017                    25994.2                    25223.4
# 2    01/03/2017                    27780.0                    26334.3
# 3    01/04/2017                    29134.3                    27045.9
# 4    01/05/2017                    27969.0                    25631.9
#
#    ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 0                 27858872.08   27591730.13       267141.956
# 1                 25994200.17   25749179.40       245020.769
# 2                 27780006.52   27472228.72       307777.804
# 3                 29134272.22   28827479.49       306792.733
# 4                 27969004.68   27569311.41       399693.262
#
#    ventas_totales_medio_pago      efectivo  tarjetas_debito  tarjetas_credito  \
# 0                27858872.08  1.023010e+07      6864575.384       9047205.493
# ...

# %%
#identificar  valores nulos por columna
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            6
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#identificar  valores nulos por dataframe
valores_nulos=data.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(42)

# %% [markdown]
# REALIZAMOS  UNA COPIA DEL DATAFRAME

# %%
#Realizamos la copia del dataframe
data3=data.copy()

# %%
#primer metodo de sustitucion de valores nulos
#sustituir valores nujlos con promedio o media
data3["salon_ventas"]=data3["salon_ventas"].fillna(round(data["salon_ventas"].mean(),1))

# %%
#identificar  valores nulos por dataframe
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         0
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#convertir dataframe a csv
data3.to_csv("nulo_promedio.csv")

# %%
#segundo metodo de sustitucion de valores nulos
#sustituir valores nulos con mediana
data3["tarjetas_debito"]=data3["tarjetas_debito"].fillna(round(data["tarjetas_debito"].median(),1))

# %%
#identificar  valores nulos por dataframe
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         0
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#convertir dataframe a csv
data3.to_csv("nulo_media_tarjeta_debito.csv")

# %%
#tercer metodo de sustitucion de valores nulos
#sustituir valores nulos por un valor numerico en concreto
data3["tarjetas_credito"]=data3["tarjetas_credito"].fillna(10)
data3
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#identificar  valores nulos por dataframe
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         0
# tarjetas_credito                        0
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#convertir dataframe a csv
data3.to_csv("nulo_numerico_tarjetas_credito.csv")

# %%
#cuarto  metodo de sustitucion de valores nulos
#sustituir valores nulos por un valor string en concreto
data3["otros_medios"]=data3["otros_medios"].fillna("2030-06-19 00:00:00")

# %%
#identificar  valores nulos por dataframe
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            0
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         0
# tarjetas_credito                        0
# otros_medios                            0
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#quinto  metodo de sustitucion de valores nulos
#sustituir valores nulos por valores no nulos hacia adelante "forward fill" 
#filtro por columnas
data3["subtotal_ventas_alimentos_bebidas"]=data3["subtotal_ventas_alimentos_bebidas"].fillna(method="ffill")
# Out:
# C:\Users\noe_s\AppData\Local\Temp\ipykernel_24312\2023099223.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["subtotal_ventas_alimentos_bebidas"]=data3["subtotal_ventas_alimentos_bebidas"].fillna(method="ffill")

# %%
#identificar  valores nulos por dataframe
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                1
# almacen                                2
# panaderia                              1
# lacteos                                1
# carnes                                 1
# verduleria_fruteria                    1
# alimentos_preparados_rotiseria         1
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    2
# electronicos_articulos_hogar           3
# ...

# %%
#sexto  metodo de sustitucion de valores nulos
#sustituir valores nulos por valores no nulos hacia atras "backward fill" 
#filtro por columnas
data3["bebidas"]=data3["bebidas"].fillna(method="bfill")
# Out:
# C:\Users\noe_s\AppData\Local\Temp\ipykernel_24312\1428694470.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["bebidas"]=data3["bebidas"].fillna(method="bfill")

# %%
#identificar  valores nulos por dataframe
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                2
# panaderia                              1
# lacteos                                1
# carnes                                 1
# verduleria_fruteria                    1
# alimentos_preparados_rotiseria         1
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    2
# electronicos_articulos_hogar           3
# ...

# %%
#primer metodo de sustitucion de valores nulos
#sustituir valores nujlos con promedio o media
data3["almacen"]=data3["almacen"].fillna(round(data["almacen"].mean(),1))

# %%
#segundo metodo de sustitucion de valores nulos
#sustituir valores nulos con mediana
data3["panaderia"]=data3["panaderia"].fillna(round(data["panaderia"].median(),1))

# %%
#tercer metodo de sustitucion de valores nulos
#sustituir valores nulos por un valor numerico en concreto
data3["lacteos"]=data3["lacteos"].fillna(10)
data3
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#cuarto  metodo de sustitucion de valores nulos
#sustituir valores nulos por un valor string en concreto
data3["carnes"]=data3["carnes"].fillna("2030-06-19 00:00:00")

# %%
#quinto  metodo de sustitucion de valores nulos
#sustituir valores nulos por valores no nulos hacia adelante "forward fill" 
#filtro por columnas
data3["verduleria_fruteria"]=data3["verduleria_fruteria"].fillna(method="ffill")
# Out:
# C:\Users\noe_s\AppData\Local\Temp\ipykernel_24312\1883891295.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["verduleria_fruteria"]=data3["verduleria_fruteria"].fillna(method="ffill")

# %%
#sexto  metodo de sustitucion de valores nulos
#sustituir valores nulos por valores no nulos hacia atras "backward fill" 
#filtro por columnas
data3["alimentos_preparados_rotiseria"]=data3["alimentos_preparados_rotiseria"].fillna(method="bfill")
# Out:
# C:\Users\noe_s\AppData\Local\Temp\ipykernel_24312\3149645882.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3["alimentos_preparados_rotiseria"]=data3["alimentos_preparados_rotiseria"].fillna(method="bfill")

# %%
#primer metodo de sustitucion de valores nulos
#sustituir valores nujlos con promedio o media
data3["indumentaria_calzado_textiles_hogar"]=data3["indumentaria_calzado_textiles_hogar"].fillna(round(data["indumentaria_calzado_textiles_hogar"].mean(),1))

# %%
#segundo metodo de sustitucion de valores nulos
#sustituir valores nulos con mediana
data3["electronicos_articulos_hogar"]=data3["electronicos_articulos_hogar"].fillna(round(data["electronicos_articulos_hogar"].median(),1))

# %%
#tercer metodo de sustitucion de valores nulos
#sustituir valores nulos por un valor numerico en concreto
data3["otros"]=data3["otros"].fillna(10)
data3
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#identificar  valores nulos por dataframe
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# ...

# %%
#convertir dataframe a csv
data3.to_csv("valores nulos_ventas_totales.csv")
